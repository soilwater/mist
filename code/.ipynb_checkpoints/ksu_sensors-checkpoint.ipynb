# %%
# Analyze for different sensors in K-State testbeds

# %%
# Import modules
import pandas as pd
import matplotlib.pyplot as plt

from bokeh.models import CustomJS, Select
from bokeh.plotting import figure, show

# %%
df = pd.read_csv(f'../data/Kansas State University/CR300-10553_Table_TE525MM.dat',skiprows=[0,2,3],parse_dates=[0], na_values="NAN")
list(df.columns[6:])
# Out:
# ['TE525MM_Rain_Tot']

# %%
def load_sensor_data(sensor):
    site_1 = pd.read_csv(f'../data/Kansas State University/CR300-23667_Table_{sensor}.dat',skiprows=[0,2,3],parse_dates=[0], na_values="NAN")
    site_2 = pd.read_csv(f'../data/Kansas State University/CR300-10553_Table_{sensor}.dat',skiprows=[0,2,3],parse_dates=[0], na_values="NAN")
    site_3 = pd.read_csv(f'../data/Kansas State University/CR300-23666_Table_{sensor}.dat',skiprows=[0,2,3],parse_dates=[0], na_values="NAN")
    
    variables = list(site_1.columns[6:])
    print(variables)
    N = len(variables)
    fig, axs = plt.subplots(N, figsize=(15,4*N))
    
    for k,var in enumerate(variables):
        print(k,var)
        axs[k].set_title(var.upper())
        axs[k].plot(site_1['TIMESTAMP'], site_1[var], label='Site 1')
        axs[k].plot(site_2['TIMESTAMP'], site_2[var], label='Site 2')
        axs[k].plot(site_3['TIMESTAMP'], site_3[var], label='Site 3')
        axs[k].legend()
        
    return axs

# %%
select_sensor = interact(load_sensor_data,
                         sensor=['Batt','Acclima','CS655','DrillDrop','GroPoint','Hydraprobe','Thetaprobe','Teros12','Teros21','TE525MM'])
# Out:
# interactive(children=(Dropdown(description='sensor', options=('Batt', 'Acclima', 'CS655', 'DrillDrop', 'GroPoi…

# %%
plt.figure(figsize=(10,6))
plt.plot(cs655['TIMESTAMP'], cs655['CS655_VWC_5_Avg'], label='CS655')
plt.plot(acclima['TIMESTAMP'], acclima['Acclima_VWC_5_Avg']/100, label='Acclima')
plt.plot(teros12['TIMESTAMP'], teros12['Teros12_VWC_5_Avg'], label='Teros 12')
plt.plot(hydraprobe['TIMESTAMP'], hydraprobe['Hydraprobe_VWC_5_Avg'], label='Hydraprobe')
plt.plot(thetaprobe['TIMESTAMP'], thetaprobe['Thetaprobe_VWC_5_Avg'], label='Thetaprobe')
plt.ylabel('Volumetric water content ($m^3/m^3$)', size=14)
plt.ylim([0.2,0.5])
plt.legend()
plt.xticks(size=14, rotation=15)
plt.yticks(size=16)

plt.twinx()
plt.step(te525['TIMESTAMP'], te525['TE525MM_Rain_Tot'])
plt.ylim([0, 50])
plt.ylabel('Precipitation (mm)', size=16)
plt.yticks(size=16)

plt.title('Site 1 - 5 cm depth', size=16)
plt.savefig('5_cm.png',dpi=300)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(cs655['TIMESTAMP'], cs655['CS655_VWC_20_Avg'], label='CS655')
plt.plot(acclima['TIMESTAMP'], acclima['Acclima_VWC_20_Avg']/100, label='Acclima')
plt.plot(teros12['TIMESTAMP'], teros12['Teros12_VWC_20_Avg'], label='Teros 12')
plt.plot(hydraprobe['TIMESTAMP'], hydraprobe['Hydraprobe_VWC_20_Avg'], label='Hydraprobe')
plt.plot(thetaprobe['TIMESTAMP'], thetaprobe['Thetaprobe_VWC_20_Avg'], label='Thetaprobe')
plt.ylabel('Volumetric water content ($m^3/m^3$)', size=14)
plt.ylim([0.2,0.6])
plt.legend()

plt.twinx()
plt.step(te525['TIMESTAMP'], te525['TE525MM_Rain_Tot'])
plt.ylim([0, 50])
plt.ylabel('Precipitation (mm)', size=14)

plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(cs655['TIMESTAMP'], cs655['CS655_VWC_40_Avg'], label='CS655')
plt.plot(acclima['TIMESTAMP'], acclima['Acclima_VWC_40_Avg']/100, label='Acclima')
plt.plot(teros12['TIMESTAMP'], teros12['Teros12_VWC_40_Avg'], label='Teros 12')
plt.plot(hydraprobe['TIMESTAMP'], hydraprobe['Hydraprobe_VWC_40_Avg'], label='Hydraprobe')
plt.plot(thetaprobe['TIMESTAMP'], thetaprobe['Thetaprobe_VWC_40_Avg'], label='Thetaprobe')
plt.ylabel('Volumetric water content ($m^3/m^3$)', size=16)
plt.ylim([0.2,0.6])
plt.legend()
plt.xticks(size=14, rotation=15)
plt.yticks(size=16)

plt.twinx()
plt.step(te525['TIMESTAMP'], te525['TE525MM_Rain_Tot'])
plt.ylim([0, 50])
plt.ylabel('Precipitation (mm)', size=16)
plt.yticks(size=16)

plt.title('Site 1 - 40 cm depth', size=16)
plt.savefig('40_cm.png',dpi=300)
plt.show()

# %%
import numpy as np

# %%
np.pi*
